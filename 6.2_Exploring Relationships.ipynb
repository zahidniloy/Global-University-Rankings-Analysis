# %% [markdown]
# # Step 1: Import Libraries and Load Data

# %%
# Import libraries for data manipulation and visualization
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set plot style
sns.set(style="whitegrid")

# Load the dataset
df = pd.read_csv('cwurData.csv')

# Display the first few rows
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# ### In this section, the necessary Python libraries for data analysis and visualization are imported.
# ### The CWUR university rankings data is then loaded from the CSV file.
# ### Displaying the first few rows provides an overview of the dataset’s structure and available variables.

# %% [markdown]
# # Step 2: Data Preparation (Drop Irrelevant Columns)

# %%
# Drop columns that are not needed for analysis
df = df.drop(columns=['world_rank', 'institution', 'country', 'year'])

# Check the dataframe structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   national_rank         2200 non-null   int64
#  1   quality_of_education  2200 non-null   int64
#  2   alumni_employment     2200 non-null   int64
#  3   quality_of_faculty    2200 non-null   int64
#  4   publications          2200 non-null   int64
#  5   influence             2200 non-null   int64
#  6   citations             2200 non-null   int64
#  7   broad_impact          2000 non-null   float64
#  8   patents               2200 non-null   int64
#  9   score                 2200 non-null   float64
# dtypes: float64(2), int64(8)
# memory usage: 172.0 KB

# %% [markdown]
# ### To ensure a focused exploratory analysis, only the relevant numerical variables are selected from the dataset.
#    ### Columns such as `institution`, `country`, and `year` are excluded,
#    ###   as they serve as identifiers or categorical data that are not suitable for correlation and distribution analysis.
# ### This step ensures that subsequent visualizations and statistical analyses are both meaningful and interpretable.

# %% [markdown]
#  # Step 3: Correlation Matrix Heatmap

# %%
# Calculate correlation matrix
corr = df.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### The correlation matrix for the selected numerical variables is computed and visualized.
# ### The heatmap uses color intensity to represent the strength and direction of relationships between pairs of variables.
# ### Strong positive correlations (close to +1) indicate variables that increase together, while strong negative correlations (close to -1) indicate inverse relationships.
# ### This visualization helps to quickly identify which metrics are most closely related within the university rankings dataset.

# %% [markdown]
# # Step 4: Scatterplot of Strongest Correlations

# %%
# Example: Scatterplot between 'quality_of_faculty' and 'score' (you can adjust based on the strongest correlation seen)

plt.figure(figsize=(8,6))
sns.scatterplot(x='quality_of_faculty', y='score', data=df)
plt.title('Scatterplot of Quality of Faculty vs Score')
plt.xlabel('Quality of Faculty')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ### Based on the correlation matrix, the pair of variables with the highest correlation coefficient is selected for a scatterplot.
# ### This visualization allows for a closer examination of the relationship, revealing trends, clusters, or outliers that may not be evident from the correlation value alone.
# ### Scatterplots are particularly useful for understanding the nature (linear or nonlinear) and strength of relationships between two variables.

# %% [markdown]
# # Step 5: Pair Plot of the Dataset

# %%
# Pairplot
sns.pairplot(df)
plt.suptitle('Pair Plot of All Variables', y=1.02)
plt.show()

# %% [markdown]
# ### A pair plot is generated to display scatterplots for each pair of numerical variables, along with histograms or density plots for each variable on the diagonal.
# ### This comprehensive visualization facilitates the exploration of potential relationships, patterns, and distributions across all variables. It also highlights variables that may warrant further investigation.

# %% [markdown]
#  # Step 6: Revisiting the Questions

# %% [markdown]
# ### Answer these based on the EDA(exploratory data analysis):
#
# ### How do specific universities' rankings evolve over time? (If time-series kept.)
#
# ### Which factors (faculty quality, alumni employment, etc.) most influence overall score?
#
# ### Are there regional differences in performance?
#
# ### New questions you noticed during analysis.

# %% [markdown]
# # Step 7: Formulating Hypotheses

# %% [markdown]
# ### hypotheses:
#
# ### H1: Higher quality_of_faculty scores are associated with higher overall scores.
#
# ### H2: Universities with more patents have better alumni employment scores.
#
# ### H3: Research output strongly correlates with publication scores.

# %% [markdown]
# # Step 8: Discussion – Insights, Questions, and Hypotheses

# %% [markdown]
# ### Insights:
# ### Step 8: Discussion – Insights, Questions, and Hypotheses
# ### The correlation matrix and scatterplots indicate that research output metrics  such as `publications` and `influence` are strongly correlated, suggesting that universities with high publication counts also tend to have greater academic influence.
# ### The pair plot further shows that some variables, like `patents`, exhibit skewed distributions, with a few institutions producing a large number of patents.
#
# ### Questions:
# ###  What factors contribute to some universities having high publication counts but lower overall scores?
# ###  Are there regional differences in the relationship between faculty quality and alumni employment?
#
# ### Hypotheses:
# ### Universities with higher research output (`publications`) are expected to have significantly higher overall scores.
# ### The impact of faculty quality on alumni employment may vary by country or region.
#
# ### These insights and questions can guide further statistical testing and more in-depth analysis in subsequent steps.
